# %%
import pandas as pd

input_file = "data\quora-dev.csv"
# input_file = "data\quora-test-student.csv"
# input_file = "data\quora-train.csv"
output_file = "data\quora-dev-sample.csv"
# output_file = "data\quora-test-student-sample.csv"
# output_file = "data\quora-train-sample.csv"

df = pd.read_csv(input_file, sep="\t")

sample_df = df.sample(n=100, random_state=42)

sample_df.to_csv(output_file, index=False, sep="\t", encoding="utf-8-sig")
